# %%
import pandas as pd

# %%
url = "dataset/comics.csv"
dados = pd.read_csv(url)
dados
# Out:
#        comicID                                              title  \
# 0        16232                           Cap Transport (2005) #12
# 1        16248                            Cap Transport (2005) #9
# 2         4990                                Halo Preview (2006)
# 3        21486  Ultimate X-Men (Spanish Language Edition) (200...
# 4        58634        A Year of Marvels: The Incredible (2016) #5
# ...        ...                                                ...
# 41222    47542               Kick-Ass 3 (2013) #1 (Ferry Variant)
# 41223    46766                               X-Factor (2005) #257
# 41224    45951                        Cable and X-Force (2012) #9
# 41225    46750           Wolverine: Sabretooth Reborn (Hardcover)
# 41226    46741                   Wolverine Comic Reader (2013) #1
#
#        issueNumber                                        description
# 0             12.0                                                NaN
# ...

# %%
dados.head(10)
# Out:
#    comicID                                              title  issueNumber  \
# 0    16232                           Cap Transport (2005) #12         12.0
# 1    16248                            Cap Transport (2005) #9          9.0
# 2     4990                                Halo Preview (2006)          0.0
# 3    21486  Ultimate X-Men (Spanish Language Edition) (200...          9.0
# 4    58634        A Year of Marvels: The Incredible (2016) #5          5.0
# 5    37534       Magician: Apprentice Riftwar Saga (2010) #17         17.0
# 6    58586  The Amazing Spider-Man (2015) #19 (Veregge Bla...         19.0
# 7    16241                           Cap Transport (2005) #20         20.0
# 8    25320                          Halo Chronicles (2009) #1          1.0
# 9    21479  Ultimate X-Men (Spanish Language Edition) (200...          1.0
#
#                                          description
# 0                                                NaN
# ...

# %%
dados.tail(10)
# Out:
#        comicID                                              title  \
# 41217    47550  Cable and X-Force (2012) #9 (Christopher Wolve...
# 41218    46739        Wolverine by Claremont & Miller (Hardcover)
# 41219    47187                            Red She-Hulk (2012) #66
# 41220    46882                            Thanos Rising (2013) #3
# 41221    47020           Age of Ultron (2013) #9 (Molina Variant)
# 41222    47542               Kick-Ass 3 (2013) #1 (Ferry Variant)
# 41223    46766                               X-Factor (2005) #257
# 41224    45951                        Cable and X-Force (2012) #9
# 41225    46750           Wolverine: Sabretooth Reborn (Hardcover)
# 41226    46741                   Wolverine Comic Reader (2013) #1
#
#        issueNumber                                        description
# 41217          9.0  Guest starring the Uncanny Avengers!\n- Hope g...
# 41218          0.0  Wolverine's vacation from the X-Men is interru...
# ...
